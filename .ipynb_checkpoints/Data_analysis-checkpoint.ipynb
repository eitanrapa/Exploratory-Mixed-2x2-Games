# %%
# %pip install numpy
# %pip install scipy

# %%
import concepts as concepts
import numpy as np
from matrix_predictions import *
from concepts import *
from IPython.display import Image
Image(filename='Format.png')

# %%
matrix = (8, 6, 0, 14, 7, 7, 10, 4)
display_matrix(matrix)
# Out:
# -------------------
# | 8      | 0      |
# |      6 |     14 |
# -------------------
# | 7      | 10     |
# |      7 |      4 |
# -------------------

# %%
game = matrix_to_game(matrix)
print(game)
# Out:
# (7, 0, 6, 4, 1, 10, 8, 3)

# %%
impulse_balance_equilibrium(game)
# Out:
# s_1 7
# s_2 6
# 7.5 6 0 10.0 7 6.5 8.5 4
# (0.16952084719853722,
#  0.8304791528014628,
#  0.3797958971132712,
#  0.6202041028867288)

# %%
scores[70]

# %%
concepts.display_matrix(games[70])

# %%
pdxns[0][70]

# %%
pdxns[1][70]

# %%
pdxns[2][70]
